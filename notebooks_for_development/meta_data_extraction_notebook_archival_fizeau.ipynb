# %%
# This scrapes data from the 2018 Fizeau AC Her data, 2018 July 9 by E.S.

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from astropy.io import fits
import asciitable
import sys
import glob, os

# %%
# read in a file and extract a meta-data field from the FITS header

dirTreeStem = ('./')
fileNameStem = ('lm_190224_')

os.chdir(dirTreeStem)

counter = 0

for f in glob.glob("*.fits"): # loop over filenames
    counter += 1 # count loops
    
    counterStart = 60
    counterStop = 11500
    if (np.logical_or(counter<counterStart,counter>counterStop)):
        continue
    
    if (counter%50 == 0):
        print('Reading in header info from frame '+str(f)+'...')
    
    # nice continuous printing of status, but can get stuck 
    #print('\r', 'Reading in header info from frame '+str(f)+'...', end='')
    #sys.stdout.flush()
    
    image, header = fits.getdata(dirTreeStem+f,0,header=True)
    
    
    # initialize dictionary with empty lists for each key, if this is first loop iteration
    if (counter==counterStart):
        data_ascii = {}
        for k in header:
            data_ascii[k] = [] 
        data_ascii['NODPOS'] = [] # manually add in header keys that don't appear in all frames
        data_ascii['DATAFLAG'] = []
        data_ascii['BADROWS'] = []
        data_ascii['FRAMENUM'] = []
    

    # append data from frames   
    for l in data_ascii:
        if l in header:
            data_ascii[l].append(header[l])
        else:
            if (l!='FRAMENUM'):
                data_ascii[l].append(np.nan) # if a flag doesn't appear in the header
            else:
                split_underscore = f.split("_") # to get frame number
                #print(split_underscore)
                split_final = split_underscore[2].split(".")
                data_ascii[l].append(split_final[0])
                
    #print(np.shape(data_ascii))
# Out:
# Reading in header info from frame lm_180524_000090.fits...
# Reading in header info from frame lm_180524_000144.fits...
# Reading in header info from frame lm_180524_000197.fits...
# Reading in header info from frame lm_180524_000250.fits...
# Reading in header info from frame lm_180524_000304.fits...
# Reading in header info from frame lm_180524_000357.fits...
# Reading in header info from frame lm_180524_000410.fits...
# Reading in header info from frame lm_180524_000464.fits...
# Reading in header info from frame lm_180524_000502.fits...
# Reading in header info from frame lm_180524_000555.fits...
# Reading in header info from frame lm_180524_000609.fits...
# Reading in header info from frame lm_180524_000662.fits...
# Reading in header info from frame lm_180524_000715.fits...
# Reading in header info from frame lm_180524_000754.fits...
# Reading in header info from frame lm_180524_000807.fits...
# Reading in header info from frame lm_180524_000861.fits...
# Reading in header info from frame lm_180524_000914.fits...
# Reading in header info from frame lm_180524_000967.fits...
# Reading in header info from frame lm_180524_000991.fits...
# Reading in header info from frame lm_180524_001044.fits...
# Reading in header info from frame lm_180524_001097.fits...
# Reading in header info from frame lm_180524_001151.fits...
# Reading in header info from frame lm_180524_001204.fits...
# Reading in header info from frame lm_180524_001242.fits...
# Reading in header info from frame lm_180524_001296.fits...
# Reading in header info from frame lm_180524_001349.fits...
# Reading in header info from frame lm_180524_001402.fits...
# Reading in header info from frame lm_180524_001260.fits...
# Reading in header info from frame lm_180524_001494.fits...
# Reading in header info from frame lm_180524_001547.fits...
# Reading in header info from frame lm_180524_001601.fits...
# Reading in header info from frame lm_180524_001654.fits...
# Reading in header info from frame lm_180524_001693.fits...
# Reading in header info from frame lm_180524_001746.fits...
# Reading in header info from frame lm_180524_001799.fits...
# Reading in header info from frame lm_180524_001853.fits...
# Reading in header info from frame lm_180524_001906.fits...
# Reading in header info from frame lm_180524_001944.fits...
# Reading in header info from frame lm_180524_001998.fits...
# Reading in header info from frame lm_180524_002051.fits...
# Reading in header info from frame lm_180524_002104.fits...
# Reading in header info from frame lm_180524_002158.fits...
# Reading in header info from frame lm_180524_002196.fits...
# Reading in header info from frame lm_180524_002249.fits...
# Reading in header info from frame lm_180524_002303.fits...
# Reading in header info from frame lm_180524_002356.fits...
# Reading in header info from frame lm_180524_002409.fits...
# Reading in header info from frame lm_180524_002448.fits...
# Reading in header info from frame lm_180524_002501.fits...
# Reading in header info from frame lm_180524_002554.fits...
# Reading in header info from frame lm_180524_002608.fits...
# Reading in header info from frame lm_180524_002540.fits...
# Reading in header info from frame lm_180524_002699.fits...
# Reading in header info from frame lm_180524_002753.fits...
# Reading in header info from frame lm_180524_002806.fits...
# Reading in header info from frame lm_180524_002859.fits...
# Reading in header info from frame lm_180524_002898.fits...
# Reading in header info from frame lm_180524_002951.fits...
# Reading in header info from frame lm_180524_003005.fits...
# Reading in header info from frame lm_180524_003058.fits...
# Reading in header info from frame lm_180524_003111.fits...
# Reading in header info from frame lm_180524_003150.fits...
# Reading in header info from frame lm_180524_003203.fits...
# Reading in header info from frame lm_180524_003256.fits...
# Reading in header info from frame lm_180524_003310.fits...
# Reading in header info from frame lm_180524_003363.fits...
# Reading in header info from frame lm_180524_003401.fits...
# Reading in header info from frame lm_180524_003455.fits...
# Reading in header info from frame lm_180524_003508.fits...
# Reading in header info from frame lm_180524_003561.fits...
# Reading in header info from frame lm_180524_003404.fits...
# Reading in header info from frame lm_180524_003653.fits...
# Reading in header info from frame lm_180524_003706.fits...
# Reading in header info from frame lm_180524_003760.fits...
# Reading in header info from frame lm_180524_003813.fits...
# Reading in header info from frame lm_180524_003820.fits...
# Reading in header info from frame lm_180524_003905.fits...
# Reading in header info from frame lm_180524_003958.fits...
# Reading in header info from frame lm_180524_004011.fits...
# Reading in header info from frame lm_180524_004065.fits...
# Reading in header info from frame lm_180524_004103.fits...
# Reading in header info from frame lm_180524_004157.fits...
# Reading in header info from frame lm_180524_004210.fits...
# Reading in header info from frame lm_180524_004263.fits...
# Reading in header info from frame lm_180524_004317.fits...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-3e9ba19b60ef> in <module>()
#      24     #sys.stdout.flush()
#      25
# ---> 26     image, header = fits.getdata(dirTreeStem+f,0,header=True)
#      27
#      28
#
# /home/unasemaje/anaconda3/lib/python3.5/site-packages/astropy/io/fits/convenience.py in getdata(filename, *args, **kwargs)
#     195     view = kwargs.pop('view', None)
#     196
# --> 197     hdulist, extidx = _getext(filename, mode, *args, **kwargs)
#     198     try:
#     199         hdu = hdulist[extidx]
#
# /home/unasemaje/anaconda3/lib/python3.5/site-packages/astropy/io/fits/convenience.py in _getext(filename, mode, *args, **kwargs)
#     997         raise TypeError('extver alone cannot specify an extension.')
#     998
# --> 999     hdulist = fitsopen(filename, mode=mode, **kwargs)
#    1000
#    1001     return hdulist, ext
#
# /home/unasemaje/anaconda3/lib/python3.5/site-packages/astropy/io/fits/hdu/hdulist.py in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     160
#     161     return HDUList.fromfile(name, mode, memmap, save_backup, cache,
# --> 162                             lazy_load_hdus, **kwargs)
#     163
#     164
#
# /home/unasemaje/anaconda3/lib/python3.5/site-packages/astropy/io/fits/hdu/hdulist.py in fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     411         return cls._readfrom(fileobj=fileobj, mode=mode, memmap=memmap,
#     412                              save_backup=save_backup, cache=cache,
# --> 413                              lazy_load_hdus=lazy_load_hdus, **kwargs)
#     414
#     415     @classmethod
#
# /home/unasemaje/anaconda3/lib/python3.5/site-packages/astropy/io/fits/hdu/hdulist.py in _readfrom(cls, fileobj, data, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     999             if not isinstance(fileobj, _File):
#    1000                 # instantiate a FITS file object (ffo)
# -> 1001                 fileobj = _File(fileobj, mode=mode, memmap=memmap, cache=cache)
#    1002             # The Astropy mode is determined by the _File initializer if the
#    1003             # supplied mode was None
#
# /home/unasemaje/anaconda3/lib/python3.5/site-packages/astropy/utils/decorators.py in wrapper(*args, **kwargs)
#     506                         # one with the name of the new argument to the function
#     507                         kwargs[new_name[i]] = value
# --> 508             return function(*args, **kwargs)
#     509
#     510         return wrapper
#
# /home/unasemaje/anaconda3/lib/python3.5/site-packages/astropy/io/fits/file.py in __init__(self, fileobj, mode, memmap, overwrite, cache)
#     148             self._open_fileobj(fileobj, mode, overwrite)
#     149         elif isinstance(fileobj, string_types):
# --> 150             self._open_filename(fileobj, mode, overwrite)
#     151         else:
#     152             self._open_filelike(fileobj, mode, overwrite)
#
# /home/unasemaje/anaconda3/lib/python3.5/site-packages/astropy/io/fits/file.py in _open_filename(self, filename, mode, overwrite)
#     482         if os.path.exists(self.name):
#     483             with fileobj_open(self.name, 'rb') as f:
# --> 484                 magic = f.read(4)
#     485         else:
#     486             magic = b('')
#
# KeyboardInterrupt:

# %%
# convert to pandas dataframe

data_ascii_df = pd.DataFrame.from_dict(data_ascii, orient='columns')

# %%
# write to file

data_ascii_df.to_csv('junk.csv')
