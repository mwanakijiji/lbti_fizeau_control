fits',
#  '/Users/nyumbani/Downloads/lm_180507_005775_junk.fits',
#  '/Users/nyumbani/Downloads/lm_180507_005761_junk.fits',
#  '/Users/nyumbani/Downloads/img_seen_prepradding_1578145613_1.fits',
#  '/Users/nyumbani/Downloads/fft_amp_lm_180507_005718_junk_masked_new_ver2.fits',
#  '/Users/nyumbani/Downloads/fft_amp_1578145718_0.fits',
#  '/Users/nyumbani/Downloads/lm_180507_007002_junk.fits',
#  '/Users/nyumbani/Downloads/lm_180507_006973_junk.fits',
#  '/Users/nyumbani/Downloads/lm_180507_005740_junk.fits',
#  '/Users/nyumbani/Downloads/lm_180507_005789_junk.fits',
#  '/Users/nyumbani/Downloads/fft_amp_1578146601_0.fits',
#  '/Users/nyumbani/Downloads/lm_180507_007023_junk.fits',
#  '/Users/nyumbani/Downloads/lm_180507_006952_junk.fits',
#  '/Users/nyumbani/Downloads/fft_arg_psf_trial5_00003004.fits',
#  '/Users/nyumbani/Downloads/lm_180507_005803_junk.fits',
#  '/Users/nyumbani/Downloads/lm_180507_007037_junk.fits',
#  '/Users/nyumbani/Downloads/img_seen_prepradding_lm_180507_005718_junk.fits',
#  '/Users/nyumbani/Downloads/lm_180507_005754_junk.fits',
#  '/Users/nyumbani/Downloads/lm_180507_005778_junk.fits',
#  '/Users/nyumbani/Downloads/img_when_centroiding_fringe_angle_1578146464_1.fits',
#  '/Users/nyumbani/Downloads/lm_180507_005716_junk.fits',
#  '/Users/nyumbani/Downloads/lm_180507_005784_junk.fits',
#  '/Users/nyumbani/Downloads/lm_180507_007054_junk.fits',
#  '/Users/nyumbani/Downloads/lm_200104_000003.fits',
#  '/Users/nyumbani/Downloads/lm_180507_006996_junk.fits',
#  '/Users/nyumbani/Downloads/lm_180507_005737_junk.fits',
#  '/Users/nyumbani/Downloads/fft_arg_psf_trial5_00000018.fits',
#  '/Users/nyumbani/Downloads/lm_180507_005723_junk.fits',
#  '/Users/nyumbani/Downloads/lm_180507_006982_junk.fits',
#  '/Users/nyumbani/Downloads/lm_180507_007040_junk.fits',
#  '/Users/nyumbani/Downloads/lm_180507_005790_junk.fits',
#  '/Users/nyumbani/Downloads/lm_180507_005759_junk.fits',
#  '/Users/nyumbani/Downloads/fft_arg_1578145850_2.fits']

# %%
for f in range(0,len(file_names_all)): # full dataset in HOSTS footprint: (4249,11497)
    
    image, header = fits.getdata(file_names_all[f],0,header=True) 
    
    # a quick and dirty background subtraction and bad pixel fixing
    #TBD
    
    # make plot
    plt.imshow(image, origin="lower", cmap="gray") # PSF cut-out
    plt.ylabel('y')
    plt.xlabel('x')
    plt.suptitle(str(os.path.basename(file_names_all[f])))

    plt.tight_layout()
    plt.savefig("thumbnail_"+str(os.path.basename(file_names_all[f]).split(".")[0])+".jpeg", dpi=100, overwrite=False)
    plt.clf()
    
    print('Frame '+str(os.path.basename(file_names_all[f]))+' done...')
# Out:
# Frame lm_180507_006976_junk.fits done...
# Frame lm_180507_007007_junk.fits done...
# Frame lm_180507_005764_junk.fits done...
# Frame lm_180507_005770_junk.fits done...
# Frame lm_180507_007013_junk.fits done...
# Frame lm_180507_006962_junk.fits done...
# Frame lm_180507_005751_junk.fits done...
# Frame lm_180507_005798_junk.fits done...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-89fa74c24c55> in <module>()
#      17     plt.suptitle(str(os.path.basename(file_names_all[f])))
#      18
# ---> 19     plt.tight_layout()
#      20     plt.savefig("thumbnail_"+str(os.path.basename(file_names_all[f]).split(".")[0])+".jpeg", dpi=100, overwrite=False)
#      21     plt.clf()
#
# ~/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/pyplot.py in tight_layout(pad, h_pad, w_pad, rect)
#    1350     """
#    1351     fig = gcf()
# -> 1352     fig.tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    1353
#    1354
#
# ~/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    2305         kwargs = get_tight_layout_figure(
#    2306             self, self.axes, subplotspec_list, renderer,
# -> 2307             pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    2308         self.subplots_adjust(**kwargs)
#    2309
#
# ~/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/tight_layout.py in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     347                                      subplot_list=subplot_list,
#     348                                      ax_bbox_list=ax_bbox_list,
# --> 349                                      pad=pad, h_pad=h_pad, w_pad=w_pad)
#     350
#     351     if rect is not None:
#
# ~/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/tight_layout.py in auto_adjust_subplotpars(fig, renderer, nrows_ncols, num1num2_list, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#     112             continue
#     113
# --> 114         tight_bbox_raw = union([ax.get_tightbbox(renderer) for ax in subplots
#     115                                 if ax.get_visible()])
#     116         tight_bbox = TransformedBbox(tight_bbox_raw,
#
# ~/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/tight_layout.py in <listcomp>(.0)
#     113
#     114         tight_bbox_raw = union([ax.get_tightbbox(renderer) for ax in subplots
# --> 115                                 if ax.get_visible()])
#     116         tight_bbox = TransformedBbox(tight_bbox_raw,
#     117                                      fig.transFigure.inverted())
#
# ~/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator)
#    4196             bb.append(self._right_title.get_window_extent(renderer))
#    4197
# -> 4198         bb_xaxis = self.xaxis.get_tightbbox(renderer)
#    4199         if bb_xaxis:
#    4200             bb.append(bb_xaxis)
#
# ~/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/axis.py in get_tightbbox(self, renderer)
#    1145         ticks_to_draw = self._update_ticks(renderer)
#    1146
# -> 1147         self._update_label_position(renderer)
#    1148
#    1149         # go back to just this axis's tick labels
#
# ~/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    1904         # get bounding boxes for this axis and any siblings
#    1905         # that have been set by `fig.align_xlabels()`
# -> 1906         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    1907
#    1908         x, y = self.label.get_position()
#
# ~/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick_boxes_siblings(self, renderer)
#    1888         # if we want to align labels from other axes:
#    1889         for nn, axx in enumerate(grp.get_siblings(self.axes)):
# -> 1890             ticks_to_draw = axx.xaxis._update_ticks(renderer)
#    1891             tlb, tlb2 = axx.xaxis._get_tick_bboxes(ticks_to_draw, renderer)
#    1892             bboxes.extend(tlb)
#
# ~/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/axis.py in _update_ticks(self, renderer)
#    1026
#    1027         interval = self.get_view_interval()
# -> 1028         tick_tups = list(self.iter_ticks())  # iter_ticks calls the locator
#    1029         if self._smart_bounds and tick_tups:
#    1030             # handle inverted limits
#
# ~/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/axis.py in iter_ticks(self)
#     969         Iterate through all of the major and minor ticks.
#     970         """
# --> 971         majorLocs = self.major.locator()
#     972         majorTicks = self.get_major_ticks(len(majorLocs))
#     973         self.major.formatter.set_locs(majorLocs)
#
# ~/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/ticker.py in __call__(self)
#    1952     def __call__(self):
#    1953         vmin, vmax = self.axis.get_view_interval()
# -> 1954         return self.tick_values(vmin, vmax)
#    1955
#    1956     def tick_values(self, vmin, vmax):
#
# ~/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/ticker.py in tick_values(self, vmin, vmax)
#    1960         vmin, vmax = mtransforms.nonsingular(
#    1961             vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 1962         locs = self._raw_ticks(vmin, vmax)
#    1963
#    1964         prune = self._prune
#
# ~/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/ticker.py in _raw_ticks(self, vmin, vmax)
#    1906         if self._nbins == 'auto':
#    1907             if self.axis is not None:
# -> 1908                 nbins = np.clip(self.axis.get_tick_space(),
#    1909                                 max(1, self._min_n_ticks - 1), 9)
#    1910             else:
#
# ~/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/axis.py in get_tick_space(self)
#    2122         ends = self.axes.transAxes.transform([[0, 0], [1, 0]])
#    2123         length = ((ends[1][0] - ends[0][0]) / self.axes.figure.dpi) * 72.0
# -> 2124         tick = self._get_tick(True)
#    2125         # There is a heuristic here that the aspect ratio of tick text
#    2126         # is no more than 3:1
#
# ~/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    1790         else:
#    1791             tick_kw = self._minor_tick_kw
# -> 1792         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1793
#    1794     def _get_label(self):
#
# ~/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     175
#     176         self.tick1line = self._get_tick1line()
# --> 177         self.tick2line = self._get_tick2line()
#     178         self.gridline = self._get_gridline()
#     179
#
# ~/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick2line(self)
#     486                           markersize=self._size,
#     487                           markeredgewidth=self._width,
# --> 488                           zorder=self._zorder)
#     489
#     490         l.set_transform(self.axes.get_xaxis_transform(which='tick2'))
#
# ~/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     389         self._us_dashOffset = 0
#     390
# --> 391         self.set_linestyle(linestyle)
#     392         self.set_drawstyle(drawstyle)
#     393         self.set_linewidth(linewidth)
#
# ~/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/lines.py in set_linestyle(self, ls)
#    1123         # compute the linewidth scaled dashes
#    1124         self._dashOffset, self._dashSeq = _scale_dashes(
# -> 1125             self._us_dashOffset, self._us_dashSeq, self._linewidth)
#    1126
#    1127     @docstring.dedent_interpd
#
# ~/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/lines.py in _scale_dashes(offset, dashes, lw)
#      61
#      62 def _scale_dashes(offset, dashes, lw):
# ---> 63     if not rcParams['lines.scale_dashes']:
#      64         return offset, dashes
#      65
#
# ~/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/__init__.py in __getitem__(self, key)
#     947             return None
#     948
# --> 949         val = dict.__getitem__(self, key)
#     950         if inverse_alt is not None:
#     951             return inverse_alt(val)
#
# KeyboardInterrupt:
