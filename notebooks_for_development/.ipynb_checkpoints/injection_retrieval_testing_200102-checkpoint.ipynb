# %%
# This reads in csvs of injected and retrieved OPD, tip, and tilt in Fizeau PSFs

# Created 2019 May 30 by E.S.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
#%matplotlib qt

# %%
wavel_um = 3.87
PS = 10.7

# %%
# OPD variations alone: trial 2

trial2_opd_alone_injected = pd.read_csv("../data/trial2_200102_injected.csv")
trial2_opd_alone_retrieved = pd.read_csv("../data/trial2_200102_retrieved.csv")

# meld them by the filenames
trial2_opd_alone_injected_retrieved = pd.merge(trial2_opd_alone_retrieved,
                                               trial2_opd_alone_injected,
                                               on="filename",
                                               how="inner")

# sort
trial2_opd_alone_injected_retrieved = trial2_opd_alone_injected_retrieved.sort_values(by="filename").reset_index()

# %%
# tip variations alone: trial 3

trial3_tip_alone_injected = pd.read_csv("../data/trial3_200102_injected.csv")
trial3_tip_alone_retrieved = pd.read_csv("../data/trial3_200102_retrieved.csv")

# meld them by the filenames
trial3_tip_alone_injected_retrieved = pd.merge(trial3_tip_alone_injected,
                                               trial3_tip_alone_retrieved,
                                               on="filename",
                                               how="inner")

# sort
trial3_tip_alone_injected_retrieved = trial3_tip_alone_injected_retrieved.sort_values(by="filename").reset_index()

# %%
# tilt variations alone: trial 4

trial4_tilt_alone_injected = pd.read_csv("../data/trial4_200102_injected.csv")
trial4_tilt_alone_retrieved = pd.read_csv("../data/trial4_200102_retrieved.csv")

# meld them by the filenames
trial4_tilt_alone_injected_retrieved = pd.merge(trial4_tilt_alone_injected,
                                               trial4_tilt_alone_retrieved,
                                               on="filename",
                                               how="inner")

# sort
trial4_tilt_alone_injected_retrieved = trial4_tilt_alone_injected_retrieved.sort_values(by="filename").reset_index()

# %%
# OPD, tip, tilt variations simultaneously: trial 1

trial1_opd_tip_tilt_injected = pd.read_csv("../data/trial1_200102_injected.csv")
trial1_opd_tip_tilt_retrieved = pd.read_csv("../data/trial1_200102_retrieved.csv")

# meld them by the filenames
trial1_opd_tip_tilt_injected_retrieved = pd.merge(trial1_opd_tip_tilt_injected,
                                               trial1_opd_tip_tilt_retrieved,
                                               on="filename",
                                               how="inner")

# sort
trial1_opd_tip_tilt_injected_retrieved = trial1_opd_tip_tilt_injected_retrieved.sort_values(by="filename").reset_index()

# %%
# (y,x) translation variations alone: trial 5

trial5_yx_injected = pd.read_csv("../data/trial5_200102_injected.csv")
trial5_yx_retrieved = pd.read_csv("../data/trial5_200102_retrieved.csv")

# meld them by the filenames
trial5_yx_injected_retrieved = pd.merge(trial5_yx_injected,
                                               trial5_yx_retrieved,
                                               on="filename",
                                               how="inner")

# sort
trial5_yx_injected_retrieved = trial5_yx_injected_retrieved.sort_values(by="filename").reset_index()

# %%
# OPD, tip, tilt, (y,x) translation variations all simultaneous: trial 6

trial6_opd_tip_tilt_yx_injected = pd.read_csv("../data/trial6_200102_injected.csv")
trial6_opd_tip_tilt_yx_retrieved = pd.read_csv("../data/trial6_200102_retrieved.csv")

# meld them by the filenames
trial6_opd_tip_tilt_yx_injected_retrieved = pd.merge(trial6_opd_tip_tilt_yx_injected,
                                               trial6_opd_tip_tilt_yx_retrieved,
                                               on="filename",
                                               how="right")

# sort
trial6_opd_tip_tilt_yx_injected_retrieved = trial6_opd_tip_tilt_yx_injected_retrieved.sort_values(by="filename").reset_index()

# %%
# get quantities onto common convention

# N.b.: the retrieved OPD is with respect to the nearest wavelength-multiple 
# of OPD

def convert_stuff(df_inj_choice_opd,df_inj_choice_tip,df_inj_choice_tilt,
                  df_inj_choice_x_abs,df_inj_choice_y_abs,
                 df_ret_choice_opd,df_ret_choice_tip,df_ret_choice_tilt,
                  df_ret_choice_x_abs,df_ret_choice_y_abs,
                 df_ret_time):
    '''
    INPUTS:
    df_inj_choice_opd: dataframe column of injected OPD (ex., df_inj["opd"])
    df_inj_choice_tip: " " for tip
    df_inj_choice_tip: " " for tilt
    df_inj_choice_x_abs: " " for x (absolute position)
    df_inj_choice_y_abs: " " for y (absolute position)
    df_ret_choice_opd: dataframe column of retrieved OPD (ex., df_ret["opd"])
    df_ret_choice_tip: " " for tip
    df_ret_choice_tip: " " for tilt
    df_ret_choice_x_abs: " " for x (absolute position)
    df_ret_choice_y_abs: " " for y (absolute position)
    df_ret_time: dataframe column of relative time (in sec.)
    '''

    # injected quantities
    opd_inj_unwrapped = df_inj_choice_opd
    opd_inj_simple_mod = np.mod(df_inj_choice_opd,wavel_um)
    opd_inj_positive_side = np.copy(opd_inj_simple_mod)
    opd_inj_negative_side = np.copy(opd_inj_simple_mod)
    tip_inj_unwrapped = df_inj_choice_tip
    tip_inj_simple_mod = np.mod(df_inj_choice_tip,2*PS)
    tip_inj_positive_side = np.copy(tip_inj_simple_mod)
    tip_inj_negative_side = np.copy(tip_inj_simple_mod)
    tilt_inj_unwrapped = df_inj_choice_tilt
    tilt_inj_simple_mod = np.mod(df_inj_choice_tilt,2*PS)
    tilt_inj_positive_side = np.copy(tilt_inj_simple_mod)
    tilt_inj_negative_side = np.copy(tilt_inj_simple_mod)
    #elapsed_time_inj = np.subtract(df_inj_choice["time"],df_inj_choice["time"][0])

    # retrieved quantities
    opd_ret = df_ret_choice_opd
    tip_ret = df_ret_choice_tip
    tilt_ret = df_ret_choice_tilt
    elapsed_time_ret = np.subtract(df_ret_time,df_ret_time[0])

    # injected OPDs, after wrapping, and within an OPD range of (0, +lambda/2)
    opd_inj_positive_side[
        ~np.logical_and(opd_inj_simple_mod >= 0,opd_inj_simple_mod < wavel_um/2)] = np.nan
    # injected OPDs, after wrapping, and within an OPD range of (-lambda/2, 0)
    opd_inj_negative_side[
        ~np.logical_and(opd_inj_simple_mod >= wavel_um/2,opd_inj_simple_mod < wavel_um)] = np.nan
    # translate the 'negative' side OPDs
    opd_inj_negative_side -= wavel_um

    # injected tip, after wrapping, and within a tilt range of (0, +PS)
    tip_inj_positive_side[
        ~np.logical_and(tip_inj_simple_mod >= 0,tip_inj_simple_mod < PS)] = np.nan
    # injected tips, after wrapping, and within a tip range of (-PS, 0)
    tip_inj_negative_side[
        ~np.logical_and(tip_inj_simple_mod >= PS,tip_inj_simple_mod < 2*PS)] = np.nan
    # translate the 'negative' side tips
    tip_inj_negative_side -= 2*PS

    # injected tilt, after wrapping, and within a tilt range of (0, +PS)
    tilt_inj_positive_side[
        ~np.logical_and(tilt_inj_simple_mod >= 0,tilt_inj_simple_mod < PS)] = np.nan
    # injected tilts, after wrapping, and within a tip range of (-PS, 0)
    tilt_inj_negative_side[
        ~np.logical_and(tilt_inj_simple_mod >= PS,tilt_inj_simple_mod < 2*PS)] = np.nan
    # translate the 'negative' side tilts
    tilt_inj_negative_side -= 2*PS
    
    # combine positive and negative sides, such that finite values replace the 
    # nans in the other
    opd_inj_all = np.copy(opd_inj_positive_side)
    mask_opd = np.isnan(opd_inj_positive_side)
    opd_inj_all[mask_opd] = opd_inj_negative_side[mask_opd]
    
    tip_inj_all = np.copy(tip_inj_positive_side)
    mask_tip = np.isnan(tip_inj_positive_side)
    tip_inj_all[mask_tip] = tip_inj_negative_side[mask_tip]
    
    tilt_inj_all = np.copy(tilt_inj_positive_side)
    mask_tilt = np.isnan(tilt_inj_positive_side)
    tilt_inj_all[mask_tilt] = tilt_inj_negative_side[mask_tilt]
    
    # put stuff into dictionaries
    # (note retrieved stuff is just passed back)
    injected_dict = {"tip": tip_inj_all, "tilt": tilt_inj_all, "opd": opd_inj_all, 
                     "x_abs": df_inj_choice_x_abs, "y_abs": df_inj_choice_y_abs, "elapsed_time": elapsed_time_ret}
    retrieved_dict = {"tip": tip_ret, "tilt": tilt_ret, "opd": opd_ret, 
                      "x_abs": df_ret_choice_x_abs, "y_abs": df_ret_choice_y_abs, "elapsed_time": elapsed_time_ret}
    
    return injected_dict, retrieved_dict

# %%
# generate comparable values

df_choice = trial4_tilt_alone_injected_retrieved
injected_trial4_tilt_alone, retrieved_trial4_tilt_alone = convert_stuff(
    df_inj_choice_opd = df_choice["opd_injected"],
    df_inj_choice_tip = df_choice["tip_injected"],
    df_inj_choice_tilt = df_choice["tilt_injected"],
    df_inj_choice_x_abs = np.add(50.,df_choice["x_shift_injected"]),
    df_inj_choice_y_abs = np.add(50.,df_choice["y_shift_injected"]),
    df_ret_choice_opd = df_choice["opd_retrieved"],
    df_ret_choice_tip = df_choice["tip_retrieved"],
    df_ret_choice_tilt = df_choice["tilt_retrieved"],
    df_ret_choice_x_abs = df_choice["x_center_retrieved"],
    df_ret_choice_y_abs = df_choice["y_center_retrieved"],
    df_ret_time = df_choice["time"])

df_choice = trial3_tip_alone_injected_retrieved
injected_trial3_tip_alone, retrieved_trial3_tip_alone = convert_stuff(
    df_inj_choice_opd = df_choice["opd_injected"],
    df_inj_choice_tip = df_choice["tip_injected"],
    df_inj_choice_tilt = df_choice["tilt_injected"],
    df_inj_choice_x_abs = np.add(50.,df_choice["x_shift_injected"]),
    df_inj_choice_y_abs = np.add(50.,df_choice["y_shift_injected"]),
    df_ret_choice_opd = df_choice["opd_retrieved"],
    df_ret_choice_tip = df_choice["tip_retrieved"],
    df_ret_choice_tilt = df_choice["tilt_retrieved"],
    df_ret_choice_x_abs = df_choice["x_center_retrieved"],
    df_ret_choice_y_abs = df_choice["y_center_retrieved"],
    df_ret_time = df_choice["time"])

df_choice = trial2_opd_alone_injected_retrieved
injected_trial2_opd_alone, retrieved_trial2_opd_alone = convert_stuff(
    df_inj_choice_opd = df_choice["opd_injected"],
    df_inj_choice_tip = df_choice["tip_injected"],
    df_inj_choice_tilt = df_choice["tilt_injected"],
    df_inj_choice_x_abs = np.add(50.,df_choice["x_shift_injected"]),
    df_inj_choice_y_abs = np.add(50.,df_choice["y_shift_injected"]),
    df_ret_choice_opd = df_choice["opd_retrieved"],
    df_ret_choice_tip = df_choice["tip_retrieved"],
    df_ret_choice_tilt = df_choice["tilt_retrieved"],
    df_ret_choice_x_abs = df_choice["x_center_retrieved"],
    df_ret_choice_y_abs = df_choice["y_center_retrieved"],
    df_ret_time = df_choice["time"])

df_choice = trial1_opd_tip_tilt_injected_retrieved
injected_trial1_opd_tip_tilt, retrieved_trial1_opd_tip_tilt = convert_stuff(
    df_inj_choice_opd = df_choice["opd_injected"],
    df_inj_choice_tip = df_choice["tip_injected"],
    df_inj_choice_tilt = df_choice["tilt_injected"],
    df_inj_choice_x_abs = np.add(50.,df_choice["x_shift_injected"]),
    df_inj_choice_y_abs = np.add(50.,df_choice["y_shift_injected"]),
    df_ret_choice_opd = df_choice["opd_retrieved"],
    df_ret_choice_tip = df_choice["tip_retrieved"],
    df_ret_choice_tilt = df_choice["tilt_retrieved"],
    df_ret_choice_x_abs = df_choice["x_center_retrieved"],
    df_ret_choice_y_abs = df_choice["y_center_retrieved"],
    df_ret_time = df_choice["time"])

df_choice = trial5_yx_injected_retrieved
injected_trial5_yx, retrieved_trial5_yx = convert_stuff(
    df_inj_choice_opd = df_choice["opd_injected"],
    df_inj_choice_tip = df_choice["tip_injected"],
    df_inj_choice_tilt = df_choice["tilt_injected"],
    df_inj_choice_x_abs = np.add(50.,df_choice["x_shift_injected"]),
    df_inj_choice_y_abs = np.add(50.,df_choice["y_shift_injected"]),
    df_ret_choice_opd = df_choice["opd_retrieved"],
    df_ret_choice_tip = df_choice["tip_retrieved"],
    df_ret_choice_tilt = df_choice["tilt_retrieved"],
    df_ret_choice_x_abs = df_choice["x_center_retrieved"],
    df_ret_choice_y_abs = df_choice["y_center_retrieved"],
    df_ret_time = df_choice["time"])

df_choice = trial6_opd_tip_tilt_yx_injected_retrieved
injected_trial6_opd_tip_tilt_yx, retrieved_trial6_opd_tip_tilt_yx = convert_stuff(
    df_inj_choice_opd = df_choice["opd_injected"],
    df_inj_choice_tip = df_choice["tip_injected"],
    df_inj_choice_tilt = df_choice["tilt_injected"],
    df_inj_choice_x_abs = np.add(50.,df_choice["x_shift_injected"]),
    df_inj_choice_y_abs = np.add(50.,df_choice["y_shift_injected"]),
    df_ret_choice_opd = df_choice["opd_retrieved"],
    df_ret_choice_tip = df_choice["tip_retrieved"],
    df_ret_choice_tilt = df_choice["tilt_retrieved"],
    df_ret_choice_x_abs = df_choice["x_center_retrieved"],
    df_ret_choice_y_abs = df_choice["y_center_retrieved"],
    df_ret_time = df_choice["time"])

# %%
print(df_choice["y_center_retrieved"])
print(np.add(50.,df_choice["y_shift_injected"]))
# Out:
# 0       50.0
# 1       50.0
# 2       50.0
# 3       50.0
# 4       50.0
# 5       50.0
# 6       50.0
# 7       50.0
# 8       50.0
# 9       50.0
# 10      50.0
# 11      50.0
# 12      50.0
# 13      50.0
# 14      50.0
# 15      50.0
# 16      50.0
# 17      50.0
# 18      50.0
# 19      50.0
# 20      50.0
# 21      50.0
# 22      50.0
# 23      50.0
# 24      50.0
# 25      50.0
# 26      50.0
# 27      50.0
# 28      50.0
# 29      50.0
#         ...
# 1831    48.0
# 1832    48.0
# 1833    48.0
# 1834    48.0
# 1835    48.0
# 1836    48.0
# 1837    48.0
# 1838    48.0
# 1839    48.0
# 1840    48.0
# 1841    48.0
# 1842    48.0
# 1843    48.0
# 1844    48.0
# 1845    48.0
# 1846    48.0
# 1847    48.0
# 1848    48.0
# 1849    48.0
# 1850    48.0
# 1851    48.0
# 1852    48.0
# 1853    49.0
# 1854    49.0
# 1855    48.0
# 1856    49.0
# 1857    48.0
# 1858    49.0
# 1859    49.0
# 1860    49.0
# Name: y_center_retrieved, Length: 1861, dtype: float64
# 0       50.000
# 1       50.000
# 2       49.875
# 3       49.750
# 4       49.750
# 5       49.500
# 6       49.500
# 7       49.500
# 8       49.500
# 9       49.500
# 10      49.500
# 11      49.500
# 12      49.500
# 13      49.500
# 14      49.625
# 15      49.625
# 16      49.625
# 17      49.625
# 18      49.625
# 19      49.500
# 20      49.625
# 21      49.625
# 22      49.625
# 23      49.625
# 24      49.625
# 25      49.625
# 26      49.625
# 27      49.625
# 28      49.625
# 29      49.500
#          ...
# 1831    49.750
# 1832    49.750
# 1833    49.750
# 1834    50.000
# 1835    50.000
# 1836    49.875
# 1837    50.000
# 1838    50.000
# 1839    50.000
# 1840    50.000
# 1841    50.125
# 1842    50.125
# 1843    50.250
# 1844    50.375
# 1845    50.375
# 1846    50.375
# 1847    50.250
# 1848    50.375
# 1849    50.375
# 1850    50.500
# 1851    50.625
# 1852    50.625
# 1853    50.750
# 1854    50.625
# 1855    50.625
# 1856    50.750
# 1857    50.750
# 1858    50.750
# 1859    50.750
# 1860    50.750
# Name: y_shift_injected, Length: 1861, dtype: float64

# %%
def plot_5_quantities(dict_inj, dict_ret, plot_title):
    ### PLOT NAME
    plot_name = "junk.pdf"
    
    fig = plt.figure(figsize=(12,20), constrained_layout=True)
    gs = gridspec.GridSpec(6, 1, figure=fig)

    opd_inj = dict_inj["opd"]
    opd_ret = dict_ret["opd"]
    tip_inj = dict_inj["tip"]
    tip_ret = dict_ret["tip"]
    tilt_inj = dict_inj["tilt"]
    tilt_ret = dict_ret["tilt"]
    x_pos_inj = dict_inj["x_abs"]
    x_pos_ret = dict_ret["x_abs"]
    y_pos_inj = dict_inj["y_abs"]
    y_pos_ret = dict_ret["y_abs"]
    elapsed_time_inj = dict_inj["elapsed_time"]
    elapsed_time_ret = dict_ret["elapsed_time"]

    # OPD
    ax0 = fig.add_subplot(gs[0, :])
    ax0.set_title(plot_title)
    #ax0.axvline(x=400, linestyle=":", color="gray")
    #ax0.axvline(x=1200, linestyle=":", color="gray")
    #ax0.plot(elapsed_time_inj, opd_inj, color = "b", linewidth=10, alpha=0.25)
    ax0.scatter(elapsed_time_inj,opd_inj, color="b", s=30, alpha=0.25, label="Injected")
    ax0.scatter(elapsed_time_ret,opd_ret, color="red", s=10, alpha=1, label="Retrieved")
    ax0.axhline(y=wavel_um/2, linestyle = "--")
    ax0.axhline(y=-wavel_um/2, linestyle = "--")
    ax0.annotate("$+\lambda/2$", xy=(0, 0), xytext=(40, 2.1), textcoords="data", fontsize = 15.0)
    ax0.annotate("$-\lambda/2$", xy=(0, 0), xytext=(40, -2.3), textcoords="data", fontsize = 15.0)
    #ax0.set_title("OPD, wrapped\n(blue = injected; red = retrieved)", fontsize = 18.0)
    ax0.set_xlim([0,np.max(elapsed_time_inj)])
    ax0.set_ylim([-2.5,2.5])
    ax0.set_ylabel("OPD ($\mu$m)", fontsize = 15.0)
    #ax0.set_xlabel("Elapsed time (sec)", fontsize = 15.0)
    ax0.axes.get_xaxis().set_visible(False)
    ax0.tick_params(labelsize=14)
    ax0.legend()

    # tip
    ax1 = fig.add_subplot(gs[1, :])
    #ax1.axvline(x=400, linestyle=":", color="gray")
    #ax1.axvline(x=1200, linestyle=":", color="gray")
    #ax1.plot(elapsed_time_inj, tip_inj, color = "b", linewidth=10, alpha=0.25)
    ax1.scatter(elapsed_time_inj,tip_inj, color="b", s=30, alpha=0.25)
    ax1.scatter(elapsed_time_ret, tip_ret, color="red", s=10, alpha=1)
    ax1.axhline(y=10.7, linestyle = "--")
    ax1.axhline(y=-10.7, linestyle = "--")
    ax1.annotate("$+PS$", xy=(0, 0), xytext=(40, 11.5), textcoords="data", fontsize = 15.0)
    ax1.annotate("$-PS$", xy=(0, 0), xytext=(40, -13), textcoords="data", fontsize = 15.0)
    #ax1.set_title("Tip, wrapped (y)", fontsize = 18.0)
    ax1.set_xlim([0,np.max(elapsed_time_inj)])
    ax1.set_ylim([-14,14])
    ax1.set_ylabel("Tip (y),\nwrapped  (mas)", fontsize = 15.0)
    #ax1.set_xlabel("Elapsed time (sec)", fontsize = 15.0)
    ax1.axes.get_xaxis().set_visible(False)
    ax1.tick_params(labelsize=14)

    # tilt
    ax2 = fig.add_subplot(gs[2, :])
    #ax2.axvline(x=400, linestyle=":", color="gray")
    #ax2.axvline(x=1200, linestyle=":", color="gray")
    #ax2.plot(elapsed_time_inj, tilt_inj, color = "b", linewidth=10, alpha=0.25)
    ax2.scatter(elapsed_time_inj,tilt_inj, color="b", s=30, alpha=0.25)
    ax2.scatter(elapsed_time_ret,tilt_ret, color="red", s=10, alpha=1)
    ax2.axhline(y=10.7, linestyle = "--")
    ax2.axhline(y=-10.7, linestyle = "--")
    ax2.annotate("$+PS$", xy=(0, 0), xytext=(40, 11.5), textcoords="data", fontsize = 15.0)
    ax2.annotate("$-PS$", xy=(0, 0), xytext=(40, -13), textcoords="data", fontsize = 15.0)
    #ax2.set_title("Tilt, wrapped (x)", fontsize = 18.0)
    ax2.set_xlim([0,np.max(elapsed_time_inj)])
    ax2.set_ylim([-14,14])
    ax2.set_ylabel("Tilt (x),\nwrapped (mas)", fontsize = 15.0)
    #ax2.set_xlabel("Elapsed time (sec)", fontsize = 15.0)
    ax2.tick_params(labelsize=14)

    # x-position
    ax3 = fig.add_subplot(gs[3, :])
    #ax3.axvline(x=400, linestyle=":", color="gray")
    #ax3.axvline(x=1200, linestyle=":", color="gray")
    #ax3.plot(elapsed_time_inj, x_pos_inj, color = "b", linewidth=10, alpha=0.25)
    ax3.scatter(elapsed_time_inj,x_pos_inj, color="b", s=30, alpha=0.25)
    ax3.scatter(elapsed_time_ret, x_pos_ret, color="red", s=10, alpha=1)
    #ax3.axhline(y=10.7, linestyle = "--")
    #ax3.axhline(y=-10.7, linestyle = "--")
    #ax3.annotate("$+PS$", xy=(0, 0), xytext=(40, 11.5), textcoords="data", fontsize = 15.0)
    #ax3.annotate("$-PS$", xy=(0, 0), xytext=(40, -13), textcoords="data", fontsize = 15.0)
    #ax3.set_title("Tilt, wrapped (x)", fontsize = 18.0)
    ax3.set_xlim([0,np.max(elapsed_time_inj)])
    #ax3.set_ylim([-14,14])
    ax3.set_ylabel("x (pixel)", fontsize = 15.0)
    #ax3.set_xlabel("Elapsed time (sec)", fontsize = 15.0)
    ax3.tick_params(labelsize=14)

    # y-position
    ax4 = fig.add_subplot(gs[4, :])
    #ax4.axvline(x=400, linestyle=":", color="gray")
    #ax4.axvline(x=1200, linestyle=":", color="gray")
    #ax4.plot(elapsed_time_inj, y_pos_inj, color = "b", linewidth=10, alpha=0.25)
    ax4.scatter(elapsed_time_inj,y_pos_inj, color="b", s=30, alpha=0.25)
    ax4.scatter(elapsed_time_ret, y_pos_ret, color="red", s=10, alpha=1)
    #ax4.axhline(y=10.7, linestyle = "--")
    #ax4.axhline(y=-10.7, linestyle = "--")
    #ax4.annotate("$+PS$", xy=(0, 0), xytext=(40, 11.5), textcoords="data", fontsize = 15.0)
    #ax4.annotate("$-PS$", xy=(0, 0), xytext=(40, -13), textcoords="data", fontsize = 15.0)
    #ax4.set_title("Tilt, wrapped (x)", fontsize = 18.0)
    ax4.set_xlim([0,np.max(elapsed_time_inj)])
    #ax4.set_ylim([-14,14])
    ax4.set_ylabel("y (pixel)", fontsize = 15.0)
    ax4.set_xlabel("Elapsed time (sec)", fontsize = 15.0)
    ax4.tick_params(labelsize=14)
    
    plt.tight_layout()

    plt.savefig(plot_name)
    print("Plot saved as " + plot_name)
    fig.show()

# %%
plot_5_quantities(dict_inj = injected_trial2_opd_alone, 
                  dict_ret = retrieved_trial2_opd_alone, 
                  plot_title = "Injected OPD changes alone, 200102 run")
# Out:
# /Users/nyumbani/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/figure.py:2117: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.
#   warnings.warn("This figure was using constrained_layout==True, "
# Plot saved as junk.pdf
# /Users/nyumbani/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/figure.py:457: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
plot_5_quantities(dict_inj = injected_trial3_tip_alone, 
                  dict_ret = retrieved_trial3_tip_alone, 
                  plot_title = "Injected tip changes alone, 200102 run")
# Out:
# /Users/nyumbani/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/figure.py:2117: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.
#   warnings.warn("This figure was using constrained_layout==True, "
# Plot saved as junk.pdf
# /Users/nyumbani/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/figure.py:457: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
plot_5_quantities(dict_inj = injected_trial4_tilt_alone, 
                  dict_ret = retrieved_trial4_tilt_alone, 
                  plot_title = "Injected tilt changes alone, 200102 run")
# Out:
# /Users/nyumbani/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/figure.py:2117: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.
#   warnings.warn("This figure was using constrained_layout==True, "
# Plot saved as junk.pdf
# /Users/nyumbani/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/figure.py:457: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
plot_5_quantities(dict_inj = injected_trial1_opd_tip_tilt, 
                  dict_ret = retrieved_trial1_opd_tip_tilt, 
                  plot_title = "Injected tip, tilt, and OPD changes, 200102 run")
# Out:
# /Users/nyumbani/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/figure.py:2117: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.
#   warnings.warn("This figure was using constrained_layout==True, "
# Plot saved as junk.pdf
# /Users/nyumbani/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/figure.py:457: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
plot_5_quantities(dict_inj = injected_trial5_yx, 
                  dict_ret = retrieved_trial5_yx, 
                  plot_title = "Injected (y,x) translation only, 200102 run")
# Out:
# /Users/nyumbani/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/figure.py:2117: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.
#   warnings.warn("This figure was using constrained_layout==True, "
# Plot saved as junk.pdf
# /Users/nyumbani/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/figure.py:457: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
plot_5_quantities(dict_inj = injected_trial6_opd_tip_tilt_yx, 
                  dict_ret = retrieved_trial6_opd_tip_tilt_yx, 
                  plot_title = "Injected OPD, tip, tilt, and (y,x), 200102 run")
# Out:
# /Users/nyumbani/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/figure.py:2117: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.
#   warnings.warn("This figure was using constrained_layout==True, "
# Plot saved as junk.pdf
# /Users/nyumbani/anaconda3/envs/py366/lib/python3.6/site-packages/matplotlib/figure.py:457: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
plt.scatter(injected_trial4_tilt_alone["tilt"],retrieved_trial4_tilt_alone["tilt"])
plt.show()

# %%
plt.scatter(injected_trial3_tip_alone["tip"],retrieved_trial3_tip_alone["tip"])
plt.show()

# %%
plt.scatter(injected_trial2_opd_alone["opd"],retrieved_trial2_opd_alone["opd"])
plt.show()

# %%
plt.scatter(injected_trial1_opd_tip_tilt["opd"],retrieved_trial1_opd_tip_tilt["opd"])
plt.show()

# %%
plt.scatter(injected_trial1_opd_tip_tilt["tip"],retrieved_trial1_opd_tip_tilt["tip"])
plt.show()

# %%
plt.scatter(injected_trial1_opd_tip_tilt["tilt"],retrieved_trial1_opd_tip_tilt["tilt"])
plt.show()

# %%
plt.scatter(injected_trial6_opd_tip_tilt_yx["opd"],retrieved_trial6_opd_tip_tilt_yx["opd"])
plt.show()

# %%
plt.scatter(retrieved_trial6_opd_tip_tilt_yx["elapsed_time"],retrieved_trial6_opd_tip_tilt_yx["opd"])
plt.scatter(injected_trial6_opd_tip_tilt_yx["elapsed_time"],injected_trial6_opd_tip_tilt_yx["opd"])
plt.show()

# %%
plt.scatter(injected_trial6_opd_tip_tilt_yx["tip"],retrieved_trial6_opd_tip_tilt_yx["tip"])
plt.ylim([-11,11])
plt.show()

# %%
plt.scatter(injected_trial6_opd_tip_tilt_yx["elapsed_time"],injected_trial6_opd_tip_tilt_yx["tip"],s=10)
plt.scatter(injected_trial6_opd_tip_tilt_yx["elapsed_time"],retrieved_trial6_opd_tip_tilt_yx["tip"],s=10)
#plt.ylim([-11,11])
plt.show()

# %%
plt.scatter(injected_trial6_opd_tip_tilt_yx["tilt"],retrieved_trial6_opd_tip_tilt_yx["tilt"])
plt.ylim([-11,11])
plt.show()
