# %%
# This notebook makes thumbnails of my Altair and AC Her data

# created 2018 July 7 by E.S.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
import numpy.ma as ma
from scipy import misc, signal
from astropy.io import fits
from matplotlib.colors import LogNorm
import os.path
#% matplotlib inline

# %%
from lmircam_tools import *
from lmircam_tools import overlap_psfs
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-9eb28e01ade8> in <module>()
# ----> 1 from lmircam_tools import *
#       2 from lmircam_tools import overlap_psfs
#
# /home/unasemaje/Documents/git.repos/lbti_fizeau_control/lmircam_tools/__init__.py in <module>()
#       1 import numpy as np
#       2 from numpy import ma
# ----> 3 from pyindi import *
#       4
#       5 pi = PyINDI(verbose=False)
#
# ImportError: No module named pyindi

# %%
# Altair
stem = ('/home/../../media/unasemaje/Elements/lbti_data_reduction/180507_fizeau_altair/01_fix_pixed/')

# %%
# AC Her
stem = ('/home/../../media/unasemaje/Seagate Expansion Drive/lbti_data_reduction/180524_fizeau_ac_her/raw_data/180524/')

# %%
# FOR 20180507 ALTAIR DATA
# for loop to make thumbnails of the data

#plt.figure()

for f in range(11358,11380): 

    filename_str = stem+'lm_180507_'+str("{:0>6d}".format(f))+'.fits'
    
    psf_center = [95,865] # [y,x] convention
    cutout_ctoe = 80
    
    if os.path.isfile(filename_str): # if FITS file exists in the first place

        image, header = fits.getdata(filename_str,
                                 0,
                                 header=True) 
        
        axis_span_pix = np.arange(-80,80)
        axis_span_asec = 0.0107*axis_span_pix
    
        # make plot
        plt.imshow(image[psf_center[0]-cutout_ctoe:psf_center[0]+cutout_ctoe,
                         psf_center[1]-cutout_ctoe:psf_center[1]+cutout_ctoe], origin="lower", cmap="gray", 
                   extent=[axis_span_asec[0],axis_span_asec[-1],axis_span_asec[0],axis_span_asec[-1]])  
        #plt.ylim(axis_span_asec[0],axis_span_asec[-1])
        plt.ylabel("asec")
        #plt.xlim(axis_span_asec[0],axis_span_asec[-1])
        plt.xlabel("asec")
    
        #plt.show()
    
        plt.savefig("/home/unasemaje/Downloads/thumbnail_altair_180507_data_seeing_limited_"+str("{:0>6d}".format(f))+".png", dpi=300, overwrite=False)
        plt.tight_layout()
        plt.clf()
    
        print('Frame '+str("{:0>6d}".format(f))+' done...')
    
    else:
        
        print('File not found')
# Out:
# Frame 011358 done...
# Frame 011359 done...
# Frame 011360 done...
# Frame 011361 done...
# Frame 011362 done...
# Frame 011363 done...
# Frame 011364 done...
# Frame 011365 done...
# Frame 011366 done...
# Frame 011367 done...
# Frame 011368 done...
# Frame 011369 done...
# Frame 011370 done...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-3fb3c835f124> in <module>()
#      31         #plt.show()
#      32
# ---> 33         plt.savefig("/home/unasemaje/Downloads/thumbnail_altair_180507_data_seeing_limited_"+str("{:0>6d}".format(f))+".png", dpi=300, overwrite=False)
#      34         plt.tight_layout()
#      35         plt.clf()
#
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/matplotlib/pyplot.pyc in savefig(*args, **kwargs)
#     693 def savefig(*args, **kwargs):
#     694     fig = gcf()
# ...

# %%
# FOR 20180507 ALTAIR DATA
# for loop to make thumbnails of the data

#plt.figure()

for f in range(4200,4900): 

    filename_str = stem+'lm_180507_'+str("{:0>6d}".format(f))+'.fits'
    
    psf_center = [304,850] # [y,x] convention
    cutout_ctoe = 150
    
    if os.path.isfile(filename_str): # if FITS file exists in the first place

        image, header = fits.getdata(filename_str,
                                 0,
                                 header=True) 
        
        axis_span_pix = np.arange(-150,150)
        axis_span_asec = 0.0107*axis_span_pix
    
        # make plot
        plt.imshow(image[psf_center[0]-cutout_ctoe:psf_center[0]+cutout_ctoe,
                         psf_center[1]-cutout_ctoe:psf_center[1]+cutout_ctoe], origin="lower", cmap="gray", 
                   extent=[axis_span_asec[0],axis_span_asec[-1],axis_span_asec[0],axis_span_asec[-1]])  
        #plt.ylim(axis_span_asec[0],axis_span_asec[-1])
        plt.ylabel("asec")
        #plt.xlim(axis_span_asec[0],axis_span_asec[-1])
        plt.xlabel("asec")
    
        #plt.show()
    
        plt.savefig("/home/unasemaje/Downloads/thumbnailtest_altair_180507_"+
                    str("{:0>6d}".format(f))+".png", dpi=150, overwrite=False)
        plt.tight_layout()
        plt.clf()
    
        print('Frame '+str("{:0>6d}".format(f))+' done...')
    
    else:
        
        print('File not found')
# Out:
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# File not found
# Frame 004249 done...
# Frame 004250 done...
# Frame 004251 done...
# Frame 004252 done...
# Frame 004253 done...
# Frame 004254 done...
# Frame 004255 done...
# ...

# %%
# FOR 20180524 AC HER DATA
# for loop to make thumbnails of the data

#plt.figure()

# read in a simple background
'''
str_backgrnd = stem+'lm_180524_'+str("{:0>6d}".format(2100))+'.fits'
backgd, header = fits.getdata(str_backgrnd,
                                 0,
                                 header=True) 
'''

for f in range(13248,67168): # full AC Her dataset: (83,67168)

    filename_str = stem+'lm_180524_'+str("{:0>6d}".format(f))+'.fits'
    
    if os.path.isfile(filename_str): # if FITS file exists in the first place

        image, header = fits.getdata(filename_str,
                                 0,
                                 header=True) 
    
        # subt backgrnd and mask bullet bad parts
        #image = np.subtract(image,backgd)
        image[:,1100:1300] = np.median(image)
        image[:,:300] = np.median(image)
        image[:,-300:] = np.median(image)
        
        # locate PSF
        psf_loc = overlap_psfs.find_airy_psf(image)
    
        # make plot
        plt.imshow(image, origin="lower", cmap="gray")  
        #plt.ylabel('linear')
    
        # indicate PSF position
        plt.scatter([psf_loc[1],psf_loc[1]],[psf_loc[0],psf_loc[0]], 
                    color='red',s=90, edgecolors='r',facecolors='none') # put do
    
        plt.suptitle('(y,x) = '+str(psf_loc))
    
        #plt.show()
        
        # append PSF positions to file
        outF = open("ac_her_psf_coords.csv", "a")
        outF.write(str("{:0>6d}".format(f))+','+str(psf_loc[1])+','+str(psf_loc[0]))
        outF.write("\n")
    
        plt.tight_layout()
    
        plt.savefig("images/thumbnail_acher_180524_data_"+str("{:0>6d}".format(f))+".png", dpi=150, overwrite=False)
        plt.clf()
    
        print('Frame '+str("{:0>6d}".format(f))+' done...')
outF.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-8d1ec9495ea4> in <module>()
#      16     filename_str = stem+'lm_180524_'+str("{:0>6d}".format(f))+'.fits'
#      17
# ---> 18     if os.path.isfile(filename_str): # if FITS file exists in the first place
#      19
#      20         image, header = fits.getdata(filename_str,
#
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/genericpath.pyc in isfile(path)
#      35     """Test whether a path is a regular file"""
#      36     try:
# ---> 37         st = os.stat(path)
#      38     except os.error:
#      39         return False
#
# KeyboardInterrupt:
