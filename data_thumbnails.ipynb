# %%
# This notebook makes thumbnails of my Altair and AC Her data

# created 2018 July 7 by E.S.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
import numpy.ma as ma
from scipy import misc, signal
from astropy.io import fits
from matplotlib.colors import LogNorm
import os.path
#% matplotlib inline

# %%
from lmircam_tools import *
from lmircam_tools import overlap_psfs

# %%
# Altair
stem = ('/home/../../media/unasemaje/Seagate Expansion Drive/lbti_data_reduction/180507_fizeau_altair/01_fix_pixed/')

# %%
# AC Her
stem = ('/home/../../media/unasemaje/Seagate Expansion Drive/lbti_data_reduction/180524_fizeau_ac_her/raw_data/180524/')

# %%
# FOR 20180507 ALTAIR DATA
# for loop to make thumbnails of the data

#plt.figure()

for f in range(4249,11497): # full dataset in HOSTS footprint: (4249,11497)

    filename_str = stem+'lm_180507_'+str("{:0>6d}".format(f))+'.fits'
    
    if os.path.isfile(filename_str): # if FITS file exists in the first place

        image, header = fits.getdata(filename_str,
                                 0,
                                 header=True) 
    
        # make plot
        plt.subplot(2, 1, 1) # PSF cut-out
        plt.imshow(image, origin="lower", cmap="gray")  
        plt.ylabel('linear')
    
        plt.subplot(2, 1, 2) # PSF cut-out
        plt.imshow(image, origin="lower", cmap="gray", norm=LogNorm())  
        plt.ylabel('log10')
    
        if (header['PCCLOSED']==1): # if Phasecam loop was closed
            pc_string = 'PC **CLOSED**'
        else:
            pc_string = 'PC OPEN'
    
        plt.suptitle(str("{:0>6d}".format(f)) + ', ' + pc_string)
    
        #plt.show()
    
        plt.savefig("images/thumbnail_altair_180507_data_"+str("{:0>6d}".format(f))+".png", dpi=300, overwrite=False)
        plt.clf()
    
        print('Frame '+str("{:0>6d}".format(f))+' done...')
# Out:
# Frame 004249 done...
# Frame 004250 done...
# Frame 004251 done...
# Frame 004252 done...
# Frame 004253 done...
# Frame 004254 done...
# Frame 004255 done...
# Frame 004256 done...
# Frame 004257 done...
# Frame 004258 done...
# Frame 004259 done...
# Frame 004260 done...
# Frame 004261 done...
# Frame 004262 done...
# Frame 004263 done...
# Frame 004264 done...
# Frame 004265 done...
# Frame 004266 done...
# Frame 004267 done...
# Frame 004268 done...
# Frame 004269 done...
# Frame 004270 done...
# Frame 004271 done...
# Frame 004272 done...
# Frame 004273 done...
# Frame 004274 done...
# Frame 004275 done...
# Frame 004276 done...
# Frame 004277 done...
# Frame 004278 done...
# Frame 004279 done...
# Frame 004280 done...
# Frame 004281 done...
# Frame 004282 done...
# Frame 004283 done...
# Frame 004284 done...
# Frame 004285 done...
# Frame 004286 done...
# Frame 004287 done...
# Frame 004288 done...
# Frame 004289 done...
# Frame 004290 done...
# Frame 004291 done...
# Frame 004292 done...
# Frame 004293 done...
# Frame 004294 done...
# Frame 004295 done...
# Frame 004296 done...
# Frame 004297 done...
# Frame 004298 done...
# Frame 004299 done...
# Frame 004300 done...
# Frame 004301 done...
# Frame 004302 done...
# Frame 004303 done...
# Frame 004304 done...
# Frame 004305 done...
# Frame 004306 done...
# Frame 004307 done...
# Frame 004308 done...
# Frame 004309 done...
# Frame 004310 done...
# Frame 004311 done...
# Frame 004312 done...
# Frame 004313 done...
# Frame 004314 done...
# Frame 004315 done...
# Frame 004316 done...
# Frame 004317 done...
# Frame 004318 done...
# Frame 004319 done...
# Frame 004320 done...
# Frame 004321 done...
# Frame 004322 done...
# Frame 004323 done...
# Frame 004324 done...
# Frame 004325 done...
# Frame 004326 done...
# Frame 004327 done...
# Frame 004328 done...
# Frame 004329 done...
# Frame 004330 done...
# Frame 004331 done...
# Frame 004332 done...
# Frame 004333 done...
# Frame 004334 done...
# Frame 004335 done...
# Frame 004336 done...
# Frame 004337 done...
# Frame 004338 done...
# Frame 004339 done...
# Frame 004340 done...
# Frame 004341 done...
# Frame 004342 done...
# Frame 004343 done...
# Frame 004344 done...
# Frame 004345 done...
# Frame 004346 done...
# Frame 004347 done...
# Frame 004348 done...
# Frame 004349 done...
# Frame 004350 done...
# Frame 004351 done...
# Frame 004352 done...
# Frame 004353 done...
# Frame 004354 done...
# Frame 004355 done...
# Frame 004356 done...
# Frame 004357 done...
# Frame 004358 done...
# Frame 004359 done...
# Frame 004360 done...
# Frame 004361 done...
# Frame 004362 done...
# Frame 004363 done...
# Frame 004364 done...
# Frame 004365 done...
# Frame 004366 done...
# Frame 004367 done...
# Frame 004368 done...
# Frame 004369 done...
# Frame 004370 done...
# Frame 004371 done...
# Frame 004372 done...
# Frame 004373 done...
# Frame 004374 done...
# Frame 004375 done...
# Frame 004376 done...
# Frame 004377 done...
# Frame 004378 done...
# Frame 004379 done...
# Frame 004380 done...
# Frame 004381 done...
# Frame 004382 done...

# %%
# FOR 20180524 AC HER DATA
# for loop to make thumbnails of the data

#plt.figure()

# read in a simple background
'''
str_backgrnd = stem+'lm_180524_'+str("{:0>6d}".format(2100))+'.fits'
backgd, header = fits.getdata(str_backgrnd,
                                 0,
                                 header=True) 
'''

for f in range(13248,67168): # full AC Her dataset: (83,67168)

    filename_str = stem+'lm_180524_'+str("{:0>6d}".format(f))+'.fits'
    
    if os.path.isfile(filename_str): # if FITS file exists in the first place

        image, header = fits.getdata(filename_str,
                                 0,
                                 header=True) 
    
        # subt backgrnd and mask bullet bad parts
        #image = np.subtract(image,backgd)
        image[:,1100:1300] = np.median(image)
        image[:,:300] = np.median(image)
        image[:,-300:] = np.median(image)
        
        # locate PSF
        psf_loc = overlap_psfs.find_airy_psf(image)
    
        # make plot
        plt.imshow(image, origin="lower", cmap="gray")  
        #plt.ylabel('linear')
    
        # indicate PSF position
        plt.scatter([psf_loc[1],psf_loc[1]],[psf_loc[0],psf_loc[0]], 
                    color='red',s=90, edgecolors='r',facecolors='none') # put do
    
        plt.suptitle('(y,x) = '+str(psf_loc))
    
        #plt.show()
        
        # append PSF positions to file
        outF = open("ac_her_psf_coords.csv", "a")
        outF.write(str("{:0>6d}".format(f))+','+str(psf_loc[1])+','+str(psf_loc[0]))
        outF.write("\n")
    
        plt.tight_layout()
    
        plt.savefig("images/thumbnail_acher_180524_data_"+str("{:0>6d}".format(f))+".png", dpi=150, overwrite=False)
        plt.clf()
    
        print('Frame '+str("{:0>6d}".format(f))+' done...')
outF.close()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-5-3c806205d35e> in <module>()
#      20         image, header = fits.getdata(filename_str,
#      21                                  0,
# ---> 22                                  header=True)
#      23
#      24         # subt backgrnd and mask bullet bad parts
#
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/astropy/io/fits/convenience.pyc in getdata(filename, *args, **kwargs)
#     195     view = kwargs.pop('view', None)
#     196
# --> 197     hdulist, extidx = _getext(filename, mode, *args, **kwargs)
#     198     try:
#     199         hdu = hdulist[extidx]
#
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/astropy/io/fits/convenience.pyc in _getext(filename, mode, *args, **kwargs)
#     997         raise TypeError('extver alone cannot specify an extension.')
#     998
# --> 999     hdulist = fitsopen(filename, mode=mode, **kwargs)
#    1000
#    1001     return hdulist, ext
#
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/astropy/io/fits/hdu/hdulist.pyc in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     158
#     159     return HDUList.fromfile(name, mode, memmap, save_backup, cache,
# --> 160                             lazy_load_hdus, **kwargs)
#     161
#     162
#
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/astropy/io/fits/hdu/hdulist.pyc in fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     411         return cls._readfrom(fileobj=fileobj, mode=mode, memmap=memmap,
#     412                              save_backup=save_backup, cache=cache,
# --> 413                              lazy_load_hdus=lazy_load_hdus, **kwargs)
#     414
#     415     @classmethod
#
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/astropy/io/fits/hdu/hdulist.pyc in _readfrom(cls, fileobj, data, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#    1021
#    1022         # Make sure at least the PRIMARY HDU can be read
# -> 1023         read_one = hdulist._read_next_hdu()
#    1024
#    1025         # If we're trying to read only and no header units were found,
#
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/astropy/io/fits/hdu/hdulist.pyc in _read_next_hdu(self)
#    1096                                 fileobj.seek(offset, os.SEEK_SET)
#    1097
# -> 1098                         hdu = _BaseHDU.readfrom(fileobj, **kwargs)
#    1099                     except EOFError:
#    1100                         self._read_all = True
#
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/astropy/io/fits/hdu/base.pyc in readfrom(cls, fileobj, checksum, ignore_missing_end, **kwargs)
#     330         hdu = cls._readfrom_internal(fileobj, checksum=checksum,
#     331                                      ignore_missing_end=ignore_missing_end,
# --> 332                                      **kwargs)
#     333
#     334         # If the checksum had to be checked the data may have already been read
#
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/astropy/io/fits/hdu/base.pyc in _readfrom_internal(cls, data, header, checksum, ignore_missing_end, **kwargs)
#     395             if header is None:
#     396                 header_offset = data.tell()
# --> 397                 header = Header.fromfile(data, endcard=not ignore_missing_end)
#     398             hdu_fileobj = data
#     399             data_offset = data.tell()  # *after* reading the header
#
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/astropy/io/fits/header.pyc in fromfile(cls, fileobj, sep, endcard, padding)
#     447
#     448             return cls._from_blocks(block_iter, is_binary, sep, endcard,
# --> 449                                     padding)[1]
#     450         finally:
#     451             if close_file:
#
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/astropy/io/fits/header.pyc in _from_blocks(cls, block_iter, is_binary, sep, endcard, padding)
#     501
#     502             try:
# --> 503                 block = next(blocks)
#     504             except StopIteration:
#     505                 is_eof = True
#
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/astropy/io/fits/header.pyc in block_iter(nbytes)
#     439             def block_iter(nbytes):
#     440                 while True:
# --> 441                     data = fileobj.read(nbytes)
#     442
#     443                     if data:
#
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/astropy/io/fits/file.pyc in read(self, size)
#     210             raise EOFError
#     211         try:
# --> 212             return self._file.read(size)
#     213         except IOError:
#     214             # On some versions of Python, it appears, GzipFile will raise an
#
# IOError: [Errno 5] Input/output error
